# %%
from collections import Counter
import spacy
import textacy

# %%
nlp = spacy.load("hr_core_news_lg")
nlp.max_length = 38520905

# %%
with open ("parovi_za_provuci6.txt", mode='r', encoding='utf-8') as f:
    text_master = f.read().replace("\n", " ")

# %%
doc = nlp(text_master)

# %%
parovi_prvi = []
parovi_drugi = []
i = 1

for token in doc:
    if not token.is_punct and not token.is_space:
        if (i % 2) == 0: 
            parovi_drugi.append(token.text)
        else: 
            parovi_prvi.append(token.text)
        i = i+1
        
print(i)
# Out:
# 110557

# %%
print(parovi_prvi)
print(parovi_drugi)
# Out:
# ['koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', 'koloseum', '
# ...

# %%
parovi = list(zip(parovi_prvi, parovi_drugi))

# %%
print(parovi)
# Out:
# [('koloseum', 'kombinirati'), ('koloseum', 'kompaktno'), ('koloseum', 'komunistički'), ('koloseum', 'koncepcija'), ('koloseum', 'kongres'), ('koloseum', 'konstrukcija'), ('koloseum', 'konzervatizam'), ('koloseum', 'kopirati'), ('koloseum', 'korist'), ('koloseum', 'Kos'), ('koloseum', 'kostur'), ('koloseum', 'Košir'), ('koloseum', 'krajolik'), ('koloseum', 'Kralj'), ('koloseum', 'kretanje'), ('koloseum', 'kritičar'), ('koloseum', 'kritika'), ('koloseum', 'kriza'), ('koloseum', 'Krka'), ('koloseum', 'kuća'), ('koloseum', 'kult'), ('koloseum', 'kupanje'), ('koloseum', 'kupovati'), ('koloseum', 'kurija'), ('koloseum', 'kutak'), ('koloseum', 'kvalifikacija'), ('koloseum', 'lađa'), ('koloseum', 'lampa'), ('koloseum', 'laž'), ('koloseum', 'Corbusier'), ('koloseum', 'likovni'), ('koloseum', 'likovno'), ('koloseum', 'listopadno'), ('koloseum', 'lišaj'), ('koloseum', 'logički'), ('koloseum', 'Loos'), ('koloseum', 'luksuz'), ('koloseum', 'luster'), ('koloseum', 'ljepilo'), ('koloseum', 'ljepota
# ...

# %%
import os
directory = "data"
texts = []

for filename in os.listdir(directory):
    if filename.endswith(".txt"):
        f = os.path.join(directory, filename)
        texts.append(f)

# %%
pairs = []

for text in texts:
    with open (text, mode='r', encoding='utf-8') as f:
        txt = f.read().replace("\n", " ")
    
    doc = nlp(txt)
    
    sentences = list(doc.sents)
    

    
    text_pairs_sent = []
    
    for sentence in sentences:
    
        lemma_words = []
        for token in sentence:
            if not token.is_stop and not token.is_punct and not token.is_space: 
                lemma_words.append(token.lemma_)

        text_pairs = []

        for par in parovi:
            prvi = par[0]
            drugi = par[1]
            if prvi in lemma_words:
                if drugi in lemma_words:
                    text_pairs.append(par)

        #print(text_pairs)
        text_pairs_sent.append(text_pairs)
        
    pairs.append(text_pairs_sent)

# %%
data = list(zip(texts, pairs))

# %%
data
# Out:
# [('data\\Arhitektura-1931-1-1-Redakcija.txt',
#   [[],
#    [],
#    [('materijal', 'obrtnik'),
#     ('materijal', 'tehnologija'),
#     ('obrtnik', 'tehnologija')],
#    [],
#    [('konstrukcija', 'obrt'), ('konstrukcija', 'zgrada'), ('obrt', 'zgrada')],
#    [],
#    [('materijal', 'naručitelj'),
#     ('materijal', 'obrtnik'),
#     ('naručitelj', 'obrtnik')],
#    [],
#    [('trebati', 'volja')],
#    [],
#    [],
#    []]),
#  ('data\\Arhitektura-1931-1-2-Omahen Janko.txt',
#   [[],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [('kretanje', 'kuća')],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [('kretanje', 'zgrada')],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [('pomoći', 'tehnologija')],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [],
#    [('ljepota', 'pomoći')],
#    [('trebati', 'zadaća')]]),
#  ('data\\Arhitektura-1931-1-3-Ivo Spinčić.txt',
#   [[('pojedinac', 'želja')],
#    [],
# ...

# %%
with open('rezultati/izbrojani_parovi6.txt', 'w', encoding='utf-8') as fd:
    for d in data:
        fd.write(f"{d}\n")
